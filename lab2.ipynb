# %% [markdown]
# <a href="https://colab.research.google.com/github/anisaabdulle/ICS3105-Multimedia-Labs/blob/main/lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
from pathlib import Path

paths = ["photo.jpg", "screenshot.png", "logo.png.png"]

for name in paths:
    path = Path(name)
    img = Image.open(path)
    width, height = img.size
    channels = len(img.getbands())
    compressed = path.stat().st_size
    raw_estimate = width * height * channels
    print("\nFile:", name)
    print("Format:", img.format)
    print("Mode:", img.mode)
    print("Dimensions:", width, "x", height)
    print("Channels:", channels)
    print("Compressed size:", compressed, "bytes")
    print("Estimated uncompressed size:", raw_estimate, "bytes")
    print("Approx compression ratio:", round(raw_estimate / compressed, 2))
# Out:
# File: photo.jpg
# Format: JPEG
# Mode: RGB
# Dimensions: 275 x 183
# Channels: 3
# Compressed size: 11329 bytes
# Estimated uncompressed size: 150975 bytes
# Approx compression ratio: 13.33
#
# File: screenshot.png
# Format: PNG
# Mode: RGBA
# Dimensions: 896 x 672
# Channels: 4
# Compressed size: 855361 bytes
# Estimated uncompressed size: 2408448 bytes
# Approx compression ratio: 2.82
#
# File: logo.png.png
# Format: PNG
# Mode: RGBA
# Dimensions: 386 x 363
# Channels: 4
# Compressed size: 7894 bytes
# Estimated uncompressed size: 560472 bytes
# Approx compression ratio: 71.0
